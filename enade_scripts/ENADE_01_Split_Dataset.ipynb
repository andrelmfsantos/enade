# %% [markdown]
# # Script to split Enade dataset

# %%
import pandas as pd
import os

# %%
os.chdir('C:/Users/99836932/Downloads')

# %%
data = pd.read_csv('enade_exatas.csv')
print(len(data))
print(data.columns)
data.sample(5, random_state = 43)
# Out:
# C:\Users\99836932\AppData\Local\Temp\ipykernel_10384\3180954196.py:1: DtypeWarning: Columns (4,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('enade_exatas.csv')
# 906133
# Index(['Unnamed: 0', 'ano', 'NO_CINE_AREA_ESPECIFICA', 'NO_CINE_ROTULO',
#        'modalidade', 'regiao', 'sexo', 'cor_pele', 'idade', 'renda_familiar',
#        'sit_financeira', 'sit_trabalho', 'acao_afirmativa', 'livros_lidos_ano',
#        'nota_geral', 'nt_formacao_geral', 'nt_comp_esp'],
#       dtype='object')
#         Unnamed: 0   ano                            NO_CINE_AREA_ESPECIFICA  \
# 317739      317739  2019                           Arquitetura e construção
# 456868      456868  2010                 Engenharia e profissões correlatas
# 248522      248522  2014  Computação e Tecnologias da Informação e Comun...
# 80549        80549  2005  Computação e Tecnologias da Informação e Comun...
# ...

# %%
# Number of rows by new datasets
906133/10*9
# Out:
# 815519.7000000001

# %%
# Datasets
df1 = data[:90613].drop('Unnamed: 0', axis=1)
df2 = data[90613:181226].drop('Unnamed: 0', axis=1)
df3 = data[181226:271839].drop('Unnamed: 0', axis=1)
df4 = data[271839:362453].drop('Unnamed: 0', axis=1)

df5 = data[362453:453066].drop('Unnamed: 0', axis=1)
df6 = data[453066:543679].drop('Unnamed: 0', axis=1)
df7 = data[543679:634293].drop('Unnamed: 0', axis=1)
df8 = data[634293:724906].drop('Unnamed: 0', axis=1)
df9 = data[724906:815519].drop('Unnamed: 0', axis=1)
df10 = data[815519:].drop('Unnamed: 0', axis=1)

df10.tail(5)
# Out:
#          ano   NO_CINE_AREA_ESPECIFICA          NO_CINE_ROTULO  modalidade  \
# 906128  2017  Arquitetura e construção        Engenharia civil  Presencial
# 906129  2017  Arquitetura e construção        Engenharia civil  Presencial
# 906130  2017  Arquitetura e construção        Engenharia civil  Presencial
# 906131  2017  Produção e processamento  Engenharia de produção  Presencial
# 906132  2017  Produção e processamento  Engenharia de produção  Presencial
#
#        regiao       sexo cor_pele  idade renda_familiar  \
# 906128  Norte   Feminino    Pardo     22     Até 1,5 SM
# 906129  Norte  Masculino   Branco     22   De 6 a 10 SM
# 906130  Norte   Feminino    Pardo     23    De 3 a 6 SM
# 906131  Norte   Feminino    Pardo     21    De 3 a 6 SM
# 906132  Norte   Feminino    Negro     23     Até 1,5 SM
#
#                                            sit_financeira  \
# 906128  Tenho renda, mas recebo ajuda da família ou de...
# ...

# %%
# Write csv files
os.chdir('C:/Users/99836932/Downloads/enade_data')
df1.to_csv('enade_1of10.csv', index = False)
df2.to_csv('enade_2of10.csv', index = False)
df3.to_csv('enade_3of10.csv', index = False)
df4.to_csv('enade_4of10.csv', index = False)
df5.to_csv('enade_5of10.csv', index = False)
df6.to_csv('enade_6of10.csv', index = False)
df7.to_csv('enade_7of10.csv', index = False)
df8.to_csv('enade_8of10.csv', index = False)
df9.to_csv('enade_9of10.csv', index = False)
df10.to_csv('enade_10of10.csv', index = False)
